# %%
#firstly, extracting all items inside a user's iventory (only cs2 items)
import requests
import time
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/117.0.0.0 Safari/537.36"
}
def fetch_inventory_page(steamid64: str, appid: int, contextid: int, start: str = None):
    url = f"https://steamcommunity.com/inventory/{steamid64}/{appid}/{contextid}"
    resp = requests.get(url,headers=HEADERS, timeout=15)
    resp.raise_for_status()
    return resp.json()
def inventory_items_for_user(steamid64: str, appid: int, contextid: int, delay_between_requests: float = 0.5):
    items = []
    seen_assetids = set()
    start = None

    while True:
        data = fetch_inventory_page(steamid64, appid, contextid, start)
        # check if inventory is private or empty
        if not data or "assets" not in data or "descriptions" not in data:
            # Might be private or zero items; return whatever we have or raise
            return items, data

        assets = data.get("assets", [])
        descriptions = data.get("descriptions", [])

        # Build lookup for descriptions by (classid, instanceid)
        desc_lookup = {}
        for d in descriptions:
            key = (str(d.get("classid")), str(d.get("instanceid", "0")))
            desc_lookup[key] = d

        for a in assets:
            assetid = a.get("assetid")  # unique per item
            if assetid in seen_assetids:
                continue
            seen_assetids.add(assetid)

            classid = str(a.get("classid"))
            instanceid = str(a.get("instanceid", "0"))
            desc = desc_lookup.get((classid, instanceid)) or {}

            item = {
                "assetid": assetid,
                "classid": classid,
                "instanceid": instanceid,
                "amount": a.get("amount", 1),
                "market_tradable_restriction": a.get("market_tradable_restriction"),
                # descriptive fields:
                "name": desc.get("name"),
                "type": desc.get("type"),
                "market_hash_name": desc.get("market_hash_name"),
                "tradable": desc.get("tradable"),
                "tags": desc.get("tags", []),
                "marketable": desc.get("marketable"),
                # entire desc for debugging
                "description_raw": desc
            }
            if item["tradable"] ==1 and item["marketable"] == 1:
                items.append(item)

        # pagination
        more = data.get("more_items") or False
        # some responses give 'last_assetid' to use as start; others use 'more_start'
        if more:
            start = data.get("last_assetid") or data.get("more_start")
            if not start:
                # fallback: if server indicates 'more_items' but no token, stop to avoid infinite loop
                break
            time.sleep(delay_between_requests)  # be polite
        else:
            break

    return items, data

# %%
steamid64 = "76561198923974658"   # example SteamID64
appid = 730                       # CS:GO/CS2 (confirm)
contextid = 2                     

items, raw = inventory_items_for_user(steamid64, appid, contextid)
print(f"Found {len(items)} items")
for i, it in enumerate(items[:200], start=1):
    print(f"{i}. {it['name']!r} {it['market_hash_name']!r} ({it['assetid']}) - tradable={it.get('tradable')} marketable={it.get('marketable')}")
# Out:
# Found 54 items
# 1. 'P2000 | Marsh' 'P2000 | Marsh (Factory New)' (48108791226) - tradable=1 marketable=1
# 2. 'Recoil Case' 'Recoil Case' (48108791225) - tradable=1 marketable=1
# 3. 'Tec-9 | Raw Ceramic' 'Tec-9 | Raw Ceramic (Field-Tested)' (47992409887) - tradable=1 marketable=1
# 4. 'Recoil Case' 'Recoil Case' (47992409886) - tradable=1 marketable=1
# 5. 'G3SG1 | VariCamo' 'G3SG1 | VariCamo (Field-Tested)' (47821593041) - tradable=1 marketable=1
# 6. 'Recoil Case' 'Recoil Case' (47821593040) - tradable=1 marketable=1
# 7. 'SG 553 | Night Camo' 'SG 553 | Night Camo (Battle-Scarred)' (47655223284) - tradable=1 marketable=1
# 8. 'Revolution Case' 'Revolution Case' (47655223283) - tradable=1 marketable=1
# 9. 'SSG 08 | Blue Spruce' 'SSG 08 | Blue Spruce (Field-Tested)' (47501101767) - tradable=1 marketable=1
# 10. 'Dreams & Nightmares Case' 'Dreams & Nightmares Case' (47501101766) - tradable=1 marketable=1
# 11. 'StatTrak™ MAG-7 | Insomnia' 'StatTrak™ MAG-7 | Insomnia (Battle-Scarred)' (47394323285) - tradable=1 marketable=1
# 12. 'Sticker | Aleksib (Gold) | Copenhagen 2024' 'Sticker | Aleksib (Gold) | Copenhagen 2024' (47386508166) - tradable=1 marketable=1
# 13. 'StatTrak™ M4A4 | Choppa' 'StatTrak™ M4A4 | Choppa (Field-Tested)' (47381099310) - tradable=1 marketable=1
# 14. 'FAMAS | Meow 36' 'FAMAS | Meow 36 (Minimal Wear)' (47380823343) - tradable=1 marketable=1
# 15. 'Glock-18 | Block-18' 'Glock-18 | Block-18 (Field-Tested)' (47380815253) - tradable=1 marketable=1
# 16. '★ Kukri Knife | Night Stripe' '★ Kukri Knife | Night Stripe (Field-Tested)' (47380789813) - tradable=1 marketable=1
# 17. 'Revolution Case' 'Revolution Case' (47185843227) - tradable=1 marketable=1
# 18. 'MP5-SD | Dirt Drop' 'MP5-SD | Dirt Drop (Field-Tested)' (47017281017) - tradable=1 marketable=1
# 19. 'MP9 | Buff Blue' 'MP9 | Buff Blue (Battle-Scarred)' (46861180799) - tradable=1 marketable=1
# 20. 'Sticker | Nemiga (Foil) | Austin 2025' 'Sticker | Nemiga (Foil) | Austin 2025' (46772516572) - tradable=1 marketable=1
# 21. 'Sticker | broky (Foil) | Austin 2025' 'Sticker | broky (Foil) | Austin 2025' (46497303228) - tradable=1 marketable=1
# 22. 'Sticker | m0NESY (Foil) | Austin 2025' 'Sticker | m0NESY (Foil) | Austin 2025' (46497275563) - tradable=1 marketable=1
# 23. 'Sticker | Heavygod (Gold) | Austin 2025' 'Sticker | Heavygod (Gold) | Austin 2025' (46497253994) - tradable=1 marketable=1
# 24. 'Sticker | m0NESY | Austin 2025' 'Sticker | m0NESY | Austin 2025' (46148245762) - tradable=1 marketable=1
# 25. 'Sticker | broky (Foil) | Austin 2025' 'Sticker | broky (Foil) | Austin 2025' (46148219333) - tradable=1 marketable=1
# 26. 'Sticker | TYLOO | Austin 2025' 'Sticker | TYLOO | Austin 2025' (46148217313) - tradable=1 marketable=1
# 27. 'Sticker | EliGE (Foil) | Austin 2025' 'Sticker | EliGE (Foil) | Austin 2025' (46148214852) - tradable=1 marketable=1
# 28. 'Sticker | MOUZ (Glitter) | Shanghai 2024' 'Sticker | MOUZ (Glitter) | Shanghai 2024' (46133005348) - tradable=1 marketable=1
# 29. 'Sticker | Wildcard (Foil) | Austin 2025' 'Sticker | Wildcard (Foil) | Austin 2025' (46132036204) - tradable=1 marketable=1
# 30. 'Sticker | magixx (Holo) | Austin 2025' 'Sticker | magixx (Holo) | Austin 2025' (45987081099) - tradable=1 marketable=1
# 31. 'Sticker | m0NESY | Austin 2025' 'Sticker | m0NESY | Austin 2025' (45986319959) - tradable=1 marketable=1
# 32. 'Sticker | donk (Foil) | Austin 2025' 'Sticker | donk (Foil) | Austin 2025' (45986314792) - tradable=1 marketable=1
# 33. 'Sticker | NiKo | Austin 2025' 'Sticker | NiKo | Austin 2025' (45986308420) - tradable=1 marketable=1
# 34. 'Nova | Mandrel' 'Nova | Mandrel (Factory New)' (45986284062) - tradable=1 marketable=1
# 35. 'Sticker | electronic (Holo) | Paris 2023' 'Sticker | electronic (Holo) | Paris 2023' (45943051137) - tradable=1 marketable=1
# 36. 'Fracture Case' 'Fracture Case' (45871479392) - tradable=1 marketable=1
# 37. 'Sticker | NiKo | Austin 2025' 'Sticker | NiKo | Austin 2025' (45732510491) - tradable=1 marketable=1
# 38. 'Fracture Case' 'Fracture Case' (42754392735) - tradable=1 marketable=1
# 39. 'Fracture Case' 'Fracture Case' (41072907907) - tradable=1 marketable=1
# 40. 'Fracture Case' 'Fracture Case' (40988881325) - tradable=1 marketable=1
# 41. 'Fracture Case' 'Fracture Case' (40653506177) - tradable=1 marketable=1
# 42. 'Fracture Case' 'Fracture Case' (40352470701) - tradable=1 marketable=1
# 43. 'AWP | PAW' 'AWP | PAW (Minimal Wear)' (39069764130) - tradable=1 marketable=1
# 44. 'FAMAS | ZX Spectron' 'FAMAS | ZX Spectron (Field-Tested)' (33408390949) - tradable=1 marketable=1
# 45. 'StatTrak™ MP9 | Bioleak' 'StatTrak™ MP9 | Bioleak (Field-Tested)' (32945349271) - tradable=1 marketable=1
# 46. 'Galil AR | Chromatic Aberration' 'Galil AR | Chromatic Aberration (Field-Tested)' (32888343534) - tradable=1 marketable=1
# 47. 'Five-SeveN | Boost Protocol' 'Five-SeveN | Boost Protocol (Minimal Wear)' (32888328097) - tradable=1 marketable=1
# 48. 'StatTrak™ Glock-18 | Winterized' 'StatTrak™ Glock-18 | Winterized (Minimal Wear)' (27105044325) - tradable=1 marketable=1
# 49. 'P2000 | Gnarled' 'P2000 | Gnarled (Factory New)' (26889559365) - tradable=1 marketable=1
# 50. 'AK-47 | Point Disarray' 'AK-47 | Point Disarray (Field-Tested)' (25103319014) - tradable=1 marketable=1
# 51. 'USP-S | Cyrex' 'USP-S | Cyrex (Minimal Wear)' (25044310415) - tradable=1 marketable=1
# 52. 'M4A1-S | Leaded Glass' 'M4A1-S | Leaded Glass (Field-Tested)' (24831369865) - tradable=1 marketable=1
# 53. 'Music Kit | Neck Deep, The Lowlife Pack' 'Music Kit | Neck Deep, The Lowlife Pack' (24820448486) - tradable=1 marketable=1
# 54. 'MAC-10 | Disco Tech' 'MAC-10 | Disco Tech (Field-Tested)' (24754560599) - tradable=1 marketable=1

# %%
item_summaries = []#this for latter fetch on marketoverpice
seen_names = set()#this for checking duplicates market_hash_name
for i, it in enumerate(items[:200], start=1):
    name = it['market_hash_name']
    #skip if name are already added
    if not name or name in seen_names:
        continue
    seen_names.add(name)
    summary = {
        "index": i,
        "name": it['name'],
        "market_hash_name": it['market_hash_name'],
        "tradable": it.get('tradable'),
        "marketable": it.get('marketable')
    }
    item_summaries.append(summary)

print(item_summaries)
# Out:
# [{'index': 1, 'name': 'P2000 | Marsh', 'market_hash_name': 'P2000 | Marsh (Factory New)', 'tradable': 1, 'marketable': 1}, {'index': 2, 'name': 'Recoil Case', 'market_hash_name': 'Recoil Case', 'tradable': 1, 'marketable': 1}, {'index': 3, 'name': 'Tec-9 | Raw Ceramic', 'market_hash_name': 'Tec-9 | Raw Ceramic (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 5, 'name': 'G3SG1 | VariCamo', 'market_hash_name': 'G3SG1 | VariCamo (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 7, 'name': 'SG 553 | Night Camo', 'market_hash_name': 'SG 553 | Night Camo (Battle-Scarred)', 'tradable': 1, 'marketable': 1}, {'index': 8, 'name': 'Revolution Case', 'market_hash_name': 'Revolution Case', 'tradable': 1, 'marketable': 1}, {'index': 9, 'name': 'SSG 08 | Blue Spruce', 'market_hash_name': 'SSG 08 | Blue Spruce (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 10, 'name': 'Dreams & Nightmares Case', 'market_hash_name': 'Dreams & Nightmares Case', 'tradable': 1, 'marketable': 1}, {'index': 11, 'name': 'StatTrak™ MAG-7 | Insomnia', 'market_hash_name': 'StatTrak™ MAG-7 | Insomnia (Battle-Scarred)', 'tradable': 1, 'marketable': 1}, {'index': 12, 'name': 'Sticker | Aleksib (Gold) | Copenhagen 2024', 'market_hash_name': 'Sticker | Aleksib (Gold) | Copenhagen 2024', 'tradable': 1, 'marketable': 1}, {'index': 13, 'name': 'StatTrak™ M4A4 | Choppa', 'market_hash_name': 'StatTrak™ M4A4 | Choppa (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 14, 'name': 'FAMAS | Meow 36', 'market_hash_name': 'FAMAS | Meow 36 (Minimal Wear)', 'tradable': 1, 'marketable': 1}, {'index': 15, 'name': 'Glock-18 | Block-18', 'market_hash_name': 'Glock-18 | Block-18 (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 16, 'name': '★ Kukri Knife | Night Stripe', 'market_hash_name': '★ Kukri Knife | Night Stripe (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 18, 'name': 'MP5-SD | Dirt Drop', 'market_hash_name': 'MP5-SD | Dirt Drop (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 19, 'name': 'MP9 | Buff Blue', 'market_hash_name': 'MP9 | Buff Blue (Battle-Scarred)', 'tradable': 1, 'marketable': 1}, {'index': 20, 'name': 'Sticker | Nemiga (Foil) | Austin 2025', 'market_hash_name': 'Sticker | Nemiga (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 21, 'name': 'Sticker | broky (Foil) | Austin 2025', 'market_hash_name': 'Sticker | broky (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 22, 'name': 'Sticker | m0NESY (Foil) | Austin 2025', 'market_hash_name': 'Sticker | m0NESY (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 23, 'name': 'Sticker | Heavygod (Gold) | Austin 2025', 'market_hash_name': 'Sticker | Heavygod (Gold) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 24, 'name': 'Sticker | m0NESY | Austin 2025', 'market_hash_name': 'Sticker | m0NESY | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 26, 'name': 'Sticker | TYLOO | Austin 2025', 'market_hash_name': 'Sticker | TYLOO | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 27, 'name': 'Sticker | EliGE (Foil) | Austin 2025', 'market_hash_name': 'Sticker | EliGE (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 28, 'name': 'Sticker | MOUZ (Glitter) | Shanghai 2024', 'market_hash_name': 'Sticker | MOUZ (Glitter) | Shanghai 2024', 'tradable': 1, 'marketable': 1}, {'index': 29, 'name': 'Sticker | Wildcard (Foil) | Austin 2025', 'market_hash_name': 'Sticker | Wildcard (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 30, 'name': 'Sticker | magixx (Holo) | Austin 2025', 'market_hash_name': 'Sticker | magixx (Holo) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 32, 'name': 'Sticker | donk (Foil) | Austin 2025', 'market_hash_name': 'Sticker | donk (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 33, 'name': 'Sticker | NiKo | Austin 2025', 'market_hash_name': 'Sticker | NiKo | Austin 2025', 'tradable': 1, 'marketable': 1}, {'ind ...

# %%
from playwright.async_api import async_playwright
async def login_site_and_get_cookies():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=False)  # headless=False opens a visible window
        context = await browser.new_context()

        page = await browser.new_page()
        await page.goto("http://buff.163.com")

        # Wait for login button or perform manual login
        await page.click("text=Login/Register")
        # Prepare to catch the popup (Steam login)
        async with page.expect_popup() as popup_info:
            await page.click("text=Other login methods")
            await page.wait_for_timeout(10000)
        #inputing account's info ( im using an freshly created account, without steam guard and such)
        #steam's account need to be linked on a registered buff's account.
        popup = await popup_info.value
        await popup.fill("input[type='text']", "account_")
        await popup.fill("input[type='password']", "password")
        await popup.wait_for_timeout(10000)
        await popup.wait_for_selector("button:has-text('Sign In')")
        await popup.click("button:has-text('Sign In')")
        await popup.wait_for_timeout(10000)
        await popup.locator('input[value="Sign In"]').click()

        cookies = await page.context.cookies()
        target_domain = "buff.163.com"
        filtered_cookies = []
        print(cookies)
        for cookie in cookies:
            if cookie["domain"] == target_domain:
                filtered_cookies.append(cookie)
        await page.wait_for_timeout(20000)  # wait 20 seconds for you to log in

        # Close the browser when done
        await browser.close()
        return filtered_cookies

# %%
#now, use the name of items, and fetch the current market price
#Note: we do need cookies for this request.
from urllib.parse import quote
HEADERS2 = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36",
    "Referer": "https://buff.163.com/",
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "X-Requested-With": "XMLHttpRequest"
}
def get_market_price(market_hash_name,cookies_list):
    print(market_hash_name)
    base_url = "https://buff.163.com/api/market/goods"
    url = base_url + f"?game=csgo&page_num=1&search=" +quote(market_hash_name)
    #We need the cookies input manually, or getting the cookies on a logged on browser onto steam automatically
    #Seems like buff also using session. We can copy and extract the cookies from an logged in browser, but for automation process, its not practical.
    # cookie_str = f""
    cookies = {c['name']: c['value'] for c in cookies_list}
    resp = requests.get(url,headers=HEADERS,cookies= cookies)
    #update: we wont need cookies, just change the url to http, instead of https.
    # resp = requests.get(url,headers=HEADERS2)
    if (resp.status_code == 200):
        data = resp.json()
    
    if "data" not in data or not data["data"]["items"]:
        print("No matching items found.")
        return None
    items = data["data"]["items"]

    matched_item = None
    for item in items:
        if item["market_hash_name"] == market_hash_name:
            matched_item = item
            break
    
    if not matched_item:
        print("Item found but names do not exactly match.")
        return None
    else:
    #converting the return data to match with steam's response
        result = {
            market_hash_name: {
                "lowest_price": f"${matched_item['sell_min_price']}",
                "median_price": f"${matched_item['quick_price']}",
                "volume": str(matched_item["sell_num"])
            }
    }
        return result

# %%
cookies_list = await login_site_and_get_cookies()
# Out:
# [{'name': 'Device-Id', 'value': 'r6qrEvLq4xFaBzWPH67l', 'domain': 'buff.163.com', 'path': '/', 'expires': 1799430514.388429, 'httpOnly': False, 'secure': False, 'sameSite': 'Lax'}, {'name': 'Locale-Supported', 'value': 'en', 'domain': 'buff.163.com', 'path': '/', 'expires': -1, 'httpOnly': False, 'secure': False, 'sameSite': 'Lax'}, {'name': 'game', 'value': 'csgo', 'domain': 'buff.163.com', 'path': '/', 'expires': -1, 'httpOnly': False, 'secure': False, 'sameSite': 'Lax'}, {'name': 'sessionid', 'value': '63d5903bafee77daa86a6eb8', 'domain': 'steamcommunity.com', 'path': '/', 'expires': -1, 'httpOnly': False, 'secure': True, 'sameSite': 'None'}, {'name': 'steamCountry', 'value': 'VN%7C95ff1fcd159a750b1659e80d04502aed', 'domain': 'steamcommunity.com', 'path': '/', 'expires': -1, 'httpOnly': True, 'secure': True, 'sameSite': 'None'}, {'name': 'timezoneOffset', 'value': '25200,0', 'domain': 'steamcommunity.com', 'path': '/', 'expires': 1796406544, 'httpOnly': False, 'secure': False, 'sameSite': 'Lax'}, {'name': 'steamRefresh_steam', 'value': '76561198768707643%7C%7CeyAidHlwIjogIkpXVCIsICJhbGciOiAiRWREU0EiIH0..I88_oh7fELZu3PC1RPO1ecXniNQLWNys0rQa1aIvqohwOKlvzdo-KODdnF4STN3UDo6bjtgBs_7U1jQur8RgBg', 'domain': 'login.steampowered.com', 'path': '/', 'expires': 1796406543.199001, 'httpOnly': True, 'secure': True, 'sameSite': 'None'}, {'name': 'steamLoginSecure', 'value': '76561198768707643%7C%7CeyAidHlwIjogIkpXVCIsICJhbGciOiAiRWREU0EiIH0..JVMAVVsLo2tXjoFgR1SxarYgBVvJM2P4x78jl67rsU8H_VeupA4MmHnWweJeb4rs08lm44RfFJuHlSqo2OSjBw', 'domain': 'steamcommunity.com', 'path': '/', 'expires': 1799430543.50748, 'httpOnly': True, 'secure': True, 'sameSite': 'None'}, {'name': 'steamLoginSecure', 'value': '76561198768707643%7C%7CeyAidHlwIjogIkpXVCIsICJhbGciOiAiRWREU0EiIH0..S96JXMKZZy8q3tPknx4JZOwgNCsfMEZuLFY5DDHeqMcFuh-IjEDRSJqciQfp0AI-edTPzhc3YImS4fiWrfisBg', 'domain': 'checkout.steampowered.com', 'path': '/', 'expires': 1799430543.640373, 'httpOnly': True, 'secure': True, 'sameSite': 'None'}, {'name': 'steamCountry', 'value': 'VN%7C95ff1fcd159a750b1659e80d04502aed', 'domain': 'steam.tv', 'path': '/', 'expires': -1, 'httpOnly': True, 'secure': True, 'sameSite': 'None'}, {'name': 'steamLoginSecure', 'value': '76561198768707643%7C%7CeyAidHlwIjogIkpXVCIsICJhbGciOiAiRWREU0EiIH0..TBcmS-ECvDe1qbRu1qDrlli9yxZY8eHPP2t-A0ilxfU6_bNeBuqjq17B8oDcHgehKSM_0AwC0PuFRDR8tSxyBw', 'domain': 'steam.tv', 'path': '/', 'expires': 1799430543.664552, 'httpOnly': True, 'secure': True, 'sameSite': 'No ...

# %%
import time
import random
from collections import defaultdict
data_by_timestamp = defaultdict(dict)
timestamp = int(time.time())
for item in item_summaries:
    name = item["market_hash_name"]
    price_info = get_market_price(name,cookies_list)
    
    if price_info:
        print(price_info)
        #data_by_timestamp[timestamp][name] = price_info
    #     print(f"{name}: {price_info['lowest_price']} (median: {price_info['median_price']})")
    else:
        print(f"{name}: Price not found")
    #adding delays for bypass steam's rate limiting
    time.sleep(random.uniform(4.5, 6.0))
# Out:
# P2000 | Marsh (Factory New)
# {'P2000 | Marsh (Factory New)': {'lowest_price': '$2.99', 'median_price': '$2.98', 'volume': '265'}}
# Recoil Case
# {'Recoil Case': {'lowest_price': '$1.81', 'median_price': '$1.8', 'volume': '29931'}}
# Tec-9 | Raw Ceramic (Field-Tested)
# {'Tec-9 | Raw Ceramic (Field-Tested)': {'lowest_price': '$0.06', 'median_price': '$0.06', 'volume': '232'}}
# G3SG1 | VariCamo (Field-Tested)
# {'G3SG1 | VariCamo (Field-Tested)': {'lowest_price': '$0.29', 'median_price': '$0.28', 'volume': '654'}}
# SG 553 | Night Camo (Battle-Scarred)
# {'SG 553 | Night Camo (Battle-Scarred)': {'lowest_price': '$0.06', 'median_price': '$0.05', 'volume': '60'}}
# Revolution Case
# {'Revolution Case': {'lowest_price': '$2.05', 'median_price': '$2.09', 'volume': '20211'}}
# SSG 08 | Blue Spruce (Field-Tested)
# {'SSG 08 | Blue Spruce (Field-Tested)': {'lowest_price': '$0.04', 'median_price': '$0.03', 'volume': '970'}}
# Dreams & Nightmares Case
# {'Dreams & Nightmares Case': {'lowest_price': '$8.99', 'median_price': '$8.99', 'volume': '32507'}}
# StatTrak™ MAG-7 | Insomnia (Battle-Scarred)
# {'StatTrak™ MAG-7 | Insomnia (Battle-Scarred)': {'lowest_price': '$0.5', 'median_price': '$0.49', 'volume': '123'}}
# Sticker | Aleksib (Gold) | Copenhagen 2024
# {'Sticker | Aleksib (Gold) | Copenhagen 2024': {'lowest_price': '$44.6', 'median_price': '$44.5', 'volume': '44'}}
# StatTrak™ M4A4 | Choppa (Field-Tested)
# {'StatTrak™ M4A4 | Choppa (Field-Tested)': {'lowest_price': '$1.99', 'median_price': '$1.98', 'volume': '191'}}
# FAMAS | Meow 36 (Minimal Wear)
# {'FAMAS | Meow 36 (Minimal Wear)': {'lowest_price': '$1.31', 'median_price': '$1.3', 'volume': '279'}}
# Glock-18 | Block-18 (Field-Tested)
# {'Glock-18 | Block-18 (Field-Tested)': {'lowest_price': '$3.9', 'median_price': '$3.89', 'volume': '1523'}}
# ★ Kukri Knife | Night Stripe (Field-Tested)
# {'★ Kukri Knife | Night Stripe (Field-Tested)': {'lowest_price': '$477.9', 'median_price': '$477.4', 'volume': '134'}}
# MP5-SD | Dirt Drop (Field-Tested)
# {'MP5-SD | Dirt Drop (Field-Tested)': {'lowest_price': '$0.05', 'median_price': '$0.04', 'volume': '910'}}
# MP9 | Buff Blue (Battle-Scarred)
# {'MP9 | Buff Blue (Battle-Scarred)': {'lowest_price': '$0.04', 'median_price': '$0.04', 'volume': '110'}}
# Sticker | Nemiga (Foil) | Austin 2025
# {'Sticker | Nemiga (Foil) | Austin 2025': {'lowest_price': '$1.01', 'median_price': '$1', 'volume': '595'}}
# Sticker | broky (Foil) | Austin 2025
# {'Sticker | broky (Foil) | Austin 2025': {'lowest_price': '$1.42', 'median_price': '$1.41', 'volume': '56'}}
# Sticker | m0NESY (Foil) | Austin 2025
# {'Sticker | m0NESY (Foil) | Austin 2025': {'lowest_price': '$19.3', 'median_price': '$19.2', 'volume': '188'}}
# Sticker | Heavygod (Gold) | Austin 2025
# {'Sticker | Heavygod (Gold) | Austin 2025': {'lowest_price': '$14.2', 'median_price': '$14.1', 'volume': '147'}}
# Sticker | m0NESY | Austin 2025
# {'Sticker | m0NESY | Austin 2025': {'lowest_price': '$2.9', 'median_price': '$2.89', 'volume': '139'}}
# Sticker | TYLOO | Austin 2025
# {'Sticker | TYLOO | Austin 2025': {'lowest_price': '$0.74', 'median_price': '$0.73', 'volume': '1643'}}
# Sticker | EliGE (Foil) | Austin 2025
# {'Sticker | EliGE (Foil) | Austin 2025': {'lowest_price': '$2.06', 'median_price': '$2.05', 'volume': '110'}}
# Sticker | MOUZ (Glitter) | Shanghai 2024
# {'Sticker | MOUZ (Glitter) | Shanghai 2024': {'lowest_price': '$2.93', 'median_price': '$2.92', 'volume': '283'}}
# Sticker | Wildcard (Foil) | Austin 2025
# {'Sticker | Wildcard (Foil) | Austin 2025': {'lowest_price': '$0.84', 'median_price': '$0.83', 'volume': '153'}}
# Sticker | magixx (Holo) | Austin 2025
# {'Sticker | magixx (Holo) | Austin 2025': {'lowest_price': '$6.47', 'median_price': '$6.46', 'volume': '320'}}
# Sticker | donk (Foil) | Austin 2025
# {'Sticker | donk (Foil) | Austin 2025': {'lowest_price': '$6.64', 'median_price': '$6.63', 'volume': '909'}}
# Sticker | NiKo | Austin 2025
# {'Sticker | NiKo | Austin 2025': {'lowest_price': '$2.75', 'median_price': '$2.74', 'volume': '371'}}
# Nova | Mandrel (Factory New)
# {'Nova | Mandrel (Factory New)': {'lowest_price': '$0.15', 'median_price': '$0.14', 'volume': '864'}}
# Sticker | electronic (Holo) | Paris 2023
# {'Sticker | electronic (Holo) | Paris 2023': {'lowest_price': '$4.81', 'median_price': '$4.8', 'volume': '177'}}
# Fracture Case
# {'Fracture Case': {'lowest_price': '$2.99', 'median_price': '$2.99', 'volume': '18104'}}
# AWP | PAW (Minimal Wear)
# {'AWP | PAW (Minimal Wear)': {'lowest_price': '$21', 'median_price': '$20.9', 'volume': '1626'}}
# FAMAS | ZX Spectron (Field-Tested)
# {'FAMAS | ZX Spectron (Field-Tested)': {'lowest_price': '$28.7', 'median_price': '$28.6', 'volume': '199'}}
# StatTrak™ MP9 | Bioleak (Field-Tested)
# {'StatTrak™ MP9 | Bioleak (Field-Tested)': {'lowest_price': '$1.85', 'median_price': '$1.84', 'volume': '258'}}
# Galil AR | Chromatic Aberration (Field-Tested)
# {'Galil AR | Chromatic Aberration (Field-Tested)': {'lowest_price': '$29.66', 'median_price': '$29.56', 'volume': '389'}}
# Five-SeveN | Boost Protocol (Minimal Wear)
# {'Five-SeveN | Boost Protocol (Minimal Wear)': {'lowest_price': '$39.4', 'median_price': '$39.3', 'volume': '232'}}
# StatTrak™ Glock-18 | Winterized (Minimal Wear)
# {'StatTrak™ Glock-18 | Winterized (Minimal Wear)': {'lowest_price': '$1.64', 'median_price': '$1.63', 'volume': '366'}}
# P2000 | Gnarled (Factory New)
# {'P2000 | Gnarled (Factory New)': {'lowest_price': '$5.23', 'median_price': '$5.22', 'volume': '164'}}
# AK-47 | Point Disarray (Field-Tested)
# {'AK-47 | Point Disarray (Field-Tested)': {'lowest_price': '$102', 'median_price': '$101.5', 'volume': '755'}}
# USP-S | Cyrex (Minimal Wear)
# {'USP-S | Cyrex (Minimal Wear)': {'lowest_price': '$45', 'median_price': '$45', 'volume': '435'}}
# M4A1-S | Leaded Glass (Field-Tested)
# {'M4A1-S | Leaded Glass (Field-Tested)': {'lowest_price': '$59.5', 'median_price': '$59.4', 'volume': '964'}}
# Music Kit | Neck Deep, The Lowlife Pack
# {'Music Kit | Neck Deep, The Lowlife Pack': {'lowest_price': '$23.39', 'median_price': '$23.29', 'volume': '656'}}
# MAC-10 | Disco Tech (Field-Tested)
# {'MAC-10 | Disco Tech (Field-Tested)': {'lowest_price': '$36', 'median_price': '$35.9', 'volume': '637'}}
