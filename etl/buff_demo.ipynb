# %%
#firstly, extracting all items inside a user's iventory (only cs2 items)
import requests
import time
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/117.0.0.0 Safari/537.36"
}
def fetch_inventory_page(steamid64: str, appid: int, contextid: int, start: str = None):
    url = f"https://steamcommunity.com/inventory/{steamid64}/{appid}/{contextid}"
    resp = requests.get(url,headers=HEADERS, timeout=15)
    resp.raise_for_status()
    return resp.json()
def inventory_items_for_user(steamid64: str, appid: int, contextid: int, delay_between_requests: float = 0.5):
    items = []
    seen_assetids = set()
    start = None

    while True:
        data = fetch_inventory_page(steamid64, appid, contextid, start)
        # check if inventory is private or empty
        if not data or "assets" not in data or "descriptions" not in data:
            # Might be private or zero items; return whatever we have or raise
            return items, data

        assets = data.get("assets", [])
        descriptions = data.get("descriptions", [])

        # Build lookup for descriptions by (classid, instanceid)
        desc_lookup = {}
        for d in descriptions:
            key = (str(d.get("classid")), str(d.get("instanceid", "0")))
            desc_lookup[key] = d

        for a in assets:
            assetid = a.get("assetid")  # unique per item
            if assetid in seen_assetids:
                continue
            seen_assetids.add(assetid)

            classid = str(a.get("classid"))
            instanceid = str(a.get("instanceid", "0"))
            desc = desc_lookup.get((classid, instanceid)) or {}

            item = {
                "assetid": assetid,
                "classid": classid,
                "instanceid": instanceid,
                "amount": a.get("amount", 1),
                "market_tradable_restriction": a.get("market_tradable_restriction"),
                # descriptive fields:
                "name": desc.get("name"),
                "type": desc.get("type"),
                "market_hash_name": desc.get("market_hash_name"),
                "tradable": desc.get("tradable"),
                "tags": desc.get("tags", []),
                "marketable": desc.get("marketable"),
                # entire desc for debugging
                "description_raw": desc
            }
            if item["tradable"] ==1 and item["marketable"] == 1:
                items.append(item)

        # pagination
        more = data.get("more_items") or False
        # some responses give 'last_assetid' to use as start; others use 'more_start'
        if more:
            start = data.get("last_assetid") or data.get("more_start")
            if not start:
                # fallback: if server indicates 'more_items' but no token, stop to avoid infinite loop
                break
            time.sleep(delay_between_requests)  # be polite
        else:
            break

    return items, data

# %%
steamid64 = "76561198923974658"   # example SteamID64
appid = 730                       # CS:GO/CS2 (confirm)
contextid = 2                     

items, raw = inventory_items_for_user(steamid64, appid, contextid)
print(f"Found {len(items)} items")
for i, it in enumerate(items[:200], start=1):
    print(f"{i}. {it['name']!r} {it['market_hash_name']!r} ({it['assetid']}) - tradable={it.get('tradable')} marketable={it.get('marketable')}")
# Out:
# Found 50 items
# 1. 'G3SG1 | VariCamo' 'G3SG1 | VariCamo (Field-Tested)' (47821593041) - tradable=1 marketable=1
# 2. 'Recoil Case' 'Recoil Case' (47821593040) - tradable=1 marketable=1
# 3. 'SG 553 | Night Camo' 'SG 553 | Night Camo (Battle-Scarred)' (47655223284) - tradable=1 marketable=1
# 4. 'Revolution Case' 'Revolution Case' (47655223283) - tradable=1 marketable=1
# 5. 'SSG 08 | Blue Spruce' 'SSG 08 | Blue Spruce (Field-Tested)' (47501101767) - tradable=1 marketable=1
# 6. 'Dreams & Nightmares Case' 'Dreams & Nightmares Case' (47501101766) - tradable=1 marketable=1
# 7. 'StatTrak™ MAG-7 | Insomnia' 'StatTrak™ MAG-7 | Insomnia (Battle-Scarred)' (47394323285) - tradable=1 marketable=1
# 8. 'Sticker | Aleksib (Gold) | Copenhagen 2024' 'Sticker | Aleksib (Gold) | Copenhagen 2024' (47386508166) - tradable=1 marketable=1
# 9. 'StatTrak™ M4A4 | Choppa' 'StatTrak™ M4A4 | Choppa (Field-Tested)' (47381099310) - tradable=1 marketable=1
# 10. 'FAMAS | Meow 36' 'FAMAS | Meow 36 (Minimal Wear)' (47380823343) - tradable=1 marketable=1
# 11. 'Glock-18 | Block-18' 'Glock-18 | Block-18 (Field-Tested)' (47380815253) - tradable=1 marketable=1
# 12. '★ Kukri Knife | Night Stripe' '★ Kukri Knife | Night Stripe (Field-Tested)' (47380789813) - tradable=1 marketable=1
# 13. 'Revolution Case' 'Revolution Case' (47185843227) - tradable=1 marketable=1
# 14. 'MP5-SD | Dirt Drop' 'MP5-SD | Dirt Drop (Field-Tested)' (47017281017) - tradable=1 marketable=1
# 15. 'MP9 | Buff Blue' 'MP9 | Buff Blue (Battle-Scarred)' (46861180799) - tradable=1 marketable=1
# 16. 'Sticker | Nemiga (Foil) | Austin 2025' 'Sticker | Nemiga (Foil) | Austin 2025' (46772516572) - tradable=1 marketable=1
# 17. 'Sticker | broky (Foil) | Austin 2025' 'Sticker | broky (Foil) | Austin 2025' (46497303228) - tradable=1 marketable=1
# 18. 'Sticker | m0NESY (Foil) | Austin 2025' 'Sticker | m0NESY (Foil) | Austin 2025' (46497275563) - tradable=1 marketable=1
# 19. 'Sticker | Heavygod (Gold) | Austin 2025' 'Sticker | Heavygod (Gold) | Austin 2025' (46497253994) - tradable=1 marketable=1
# 20. 'Sticker | m0NESY | Austin 2025' 'Sticker | m0NESY | Austin 2025' (46148245762) - tradable=1 marketable=1
# 21. 'Sticker | broky (Foil) | Austin 2025' 'Sticker | broky (Foil) | Austin 2025' (46148219333) - tradable=1 marketable=1
# 22. 'Sticker | TYLOO | Austin 2025' 'Sticker | TYLOO | Austin 2025' (46148217313) - tradable=1 marketable=1
# 23. 'Sticker | EliGE (Foil) | Austin 2025' 'Sticker | EliGE (Foil) | Austin 2025' (46148214852) - tradable=1 marketable=1
# 24. 'Sticker | MOUZ (Glitter) | Shanghai 2024' 'Sticker | MOUZ (Glitter) | Shanghai 2024' (46133005348) - tradable=1 marketable=1
# 25. 'Sticker | Wildcard (Foil) | Austin 2025' 'Sticker | Wildcard (Foil) | Austin 2025' (46132036204) - tradable=1 marketable=1
# 26. 'Sticker | magixx (Holo) | Austin 2025' 'Sticker | magixx (Holo) | Austin 2025' (45987081099) - tradable=1 marketable=1
# 27. 'Sticker | m0NESY | Austin 2025' 'Sticker | m0NESY | Austin 2025' (45986319959) - tradable=1 marketable=1
# 28. 'Sticker | donk (Foil) | Austin 2025' 'Sticker | donk (Foil) | Austin 2025' (45986314792) - tradable=1 marketable=1
# 29. 'Sticker | NiKo | Austin 2025' 'Sticker | NiKo | Austin 2025' (45986308420) - tradable=1 marketable=1
# 30. 'Nova | Mandrel' 'Nova | Mandrel (Factory New)' (45986284062) - tradable=1 marketable=1
# 31. 'Sticker | electronic (Holo) | Paris 2023' 'Sticker | electronic (Holo) | Paris 2023' (45943051137) - tradable=1 marketable=1
# 32. 'Fracture Case' 'Fracture Case' (45871479392) - tradable=1 marketable=1
# 33. 'Sticker | NiKo | Austin 2025' 'Sticker | NiKo | Austin 2025' (45732510491) - tradable=1 marketable=1
# 34. 'Fracture Case' 'Fracture Case' (42754392735) - tradable=1 marketable=1
# 35. 'Fracture Case' 'Fracture Case' (41072907907) - tradable=1 marketable=1
# 36. 'Fracture Case' 'Fracture Case' (40988881325) - tradable=1 marketable=1
# 37. 'Fracture Case' 'Fracture Case' (40653506177) - tradable=1 marketable=1
# 38. 'Fracture Case' 'Fracture Case' (40352470701) - tradable=1 marketable=1
# 39. 'AWP | PAW' 'AWP | PAW (Minimal Wear)' (39069764130) - tradable=1 marketable=1
# 40. 'FAMAS | ZX Spectron' 'FAMAS | ZX Spectron (Field-Tested)' (33408390949) - tradable=1 marketable=1
# 41. 'StatTrak™ MP9 | Bioleak' 'StatTrak™ MP9 | Bioleak (Field-Tested)' (32945349271) - tradable=1 marketable=1
# 42. 'Galil AR | Chromatic Aberration' 'Galil AR | Chromatic Aberration (Field-Tested)' (32888343534) - tradable=1 marketable=1
# 43. 'Five-SeveN | Boost Protocol' 'Five-SeveN | Boost Protocol (Minimal Wear)' (32888328097) - tradable=1 marketable=1
# 44. 'StatTrak™ Glock-18 | Winterized' 'StatTrak™ Glock-18 | Winterized (Minimal Wear)' (27105044325) - tradable=1 marketable=1
# 45. 'P2000 | Gnarled' 'P2000 | Gnarled (Factory New)' (26889559365) - tradable=1 marketable=1
# 46. 'AK-47 | Point Disarray' 'AK-47 | Point Disarray (Field-Tested)' (25103319014) - tradable=1 marketable=1
# 47. 'USP-S | Cyrex' 'USP-S | Cyrex (Minimal Wear)' (25044310415) - tradable=1 marketable=1
# 48. 'M4A1-S | Leaded Glass' 'M4A1-S | Leaded Glass (Field-Tested)' (24831369865) - tradable=1 marketable=1
# 49. 'Music Kit | Neck Deep, The Lowlife Pack' 'Music Kit | Neck Deep, The Lowlife Pack' (24820448486) - tradable=1 marketable=1
# 50. 'MAC-10 | Disco Tech' 'MAC-10 | Disco Tech (Field-Tested)' (24754560599) - tradable=1 marketable=1

# %%
item_summaries = []#this for latter fetch on marketoverpice
seen_names = set()#this for checking duplicates market_hash_name
for i, it in enumerate(items[:200], start=1):
    name = it['market_hash_name']
    #skip if name are already added
    if not name or name in seen_names:
        continue
    seen_names.add(name)
    summary = {
        "index": i,
        "name": it['name'],
        "market_hash_name": it['market_hash_name'],
        "tradable": it.get('tradable'),
        "marketable": it.get('marketable')
    }
    item_summaries.append(summary)

print(item_summaries)
# Out:
# [{'index': 1, 'name': 'G3SG1 | VariCamo', 'market_hash_name': 'G3SG1 | VariCamo (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 2, 'name': 'Recoil Case', 'market_hash_name': 'Recoil Case', 'tradable': 1, 'marketable': 1}, {'index': 3, 'name': 'SG 553 | Night Camo', 'market_hash_name': 'SG 553 | Night Camo (Battle-Scarred)', 'tradable': 1, 'marketable': 1}, {'index': 4, 'name': 'Revolution Case', 'market_hash_name': 'Revolution Case', 'tradable': 1, 'marketable': 1}, {'index': 5, 'name': 'SSG 08 | Blue Spruce', 'market_hash_name': 'SSG 08 | Blue Spruce (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 6, 'name': 'Dreams & Nightmares Case', 'market_hash_name': 'Dreams & Nightmares Case', 'tradable': 1, 'marketable': 1}, {'index': 7, 'name': 'StatTrak™ MAG-7 | Insomnia', 'market_hash_name': 'StatTrak™ MAG-7 | Insomnia (Battle-Scarred)', 'tradable': 1, 'marketable': 1}, {'index': 8, 'name': 'Sticker | Aleksib (Gold) | Copenhagen 2024', 'market_hash_name': 'Sticker | Aleksib (Gold) | Copenhagen 2024', 'tradable': 1, 'marketable': 1}, {'index': 9, 'name': 'StatTrak™ M4A4 | Choppa', 'market_hash_name': 'StatTrak™ M4A4 | Choppa (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 10, 'name': 'FAMAS | Meow 36', 'market_hash_name': 'FAMAS | Meow 36 (Minimal Wear)', 'tradable': 1, 'marketable': 1}, {'index': 11, 'name': 'Glock-18 | Block-18', 'market_hash_name': 'Glock-18 | Block-18 (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 12, 'name': '★ Kukri Knife | Night Stripe', 'market_hash_name': '★ Kukri Knife | Night Stripe (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 14, 'name': 'MP5-SD | Dirt Drop', 'market_hash_name': 'MP5-SD | Dirt Drop (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 15, 'name': 'MP9 | Buff Blue', 'market_hash_name': 'MP9 | Buff Blue (Battle-Scarred)', 'tradable': 1, 'marketable': 1}, {'index': 16, 'name': 'Sticker | Nemiga (Foil) | Austin 2025', 'market_hash_name': 'Sticker | Nemiga (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 17, 'name': 'Sticker | broky (Foil) | Austin 2025', 'market_hash_name': 'Sticker | broky (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 18, 'name': 'Sticker | m0NESY (Foil) | Austin 2025', 'market_hash_name': 'Sticker | m0NESY (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 19, 'name': 'Sticker | Heavygod (Gold) | Austin 2025', 'market_hash_name': 'Sticker | Heavygod (Gold) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 20, 'name': 'Sticker | m0NESY | Austin 2025', 'market_hash_name': 'Sticker | m0NESY | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 22, 'name': 'Sticker | TYLOO | Austin 2025', 'market_hash_name': 'Sticker | TYLOO | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 23, 'name': 'Sticker | EliGE (Foil) | Austin 2025', 'market_hash_name': 'Sticker | EliGE (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 24, 'name': 'Sticker | MOUZ (Glitter) | Shanghai 2024', 'market_hash_name': 'Sticker | MOUZ (Glitter) | Shanghai 2024', 'tradable': 1, 'marketable': 1}, {'index': 25, 'name': 'Sticker | Wildcard (Foil) | Austin 2025', 'market_hash_name': 'Sticker | Wildcard (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 26, 'name': 'Sticker | magixx (Holo) | Austin 2025', 'market_hash_name': 'Sticker | magixx (Holo) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 28, 'name': 'Sticker | donk (Foil) | Austin 2025', 'market_hash_name': 'Sticker | donk (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 29, 'name': 'Sticker | NiKo | Austin 2025', 'market_hash_name': 'Sticker | NiKo | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 30, 'name': 'Nova | Mandrel', 'market_hash_name': 'Nova | Mandrel (Factory New)', 'tradable': 1, 'marketable': 1}, {'index': 31, 'name': 'Sticker | electronic (Holo) | Paris 2023', 'market_hash_name': 'Sticker | electronic (Holo) | Paris 2023', 'tradable': ...

# %%
from playwright.async_api import async_playwright
async def login_site_and_get_cookies():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=False)  # headless=False opens a visible window
        context = await browser.new_context()

        page = await browser.new_page()
        await page.goto("http://buff.163.com")

        # Wait for login button or perform manual login
        await page.click("text=Login/Register")
        # Prepare to catch the popup (Steam login)
        async with page.expect_popup() as popup_info:
            await page.click("text=Other login methods")
            await page.wait_for_timeout(10000)
        #inputing account's info ( im using an freshly created account, without steam guard and such)
        #steam's account need to be linked on a registered buff's account.
        popup = await popup_info.value
        await popup.fill("input[type='text']", "account_")
        await popup.fill("input[type='password']", "password")
        await popup.wait_for_timeout(10000)
        await popup.wait_for_selector("button:has-text('Sign In')")
        await popup.click("button:has-text('Sign In')")
        await popup.wait_for_timeout(10000)
        await popup.locator('input[value="Sign In"]').click()

        cookies = await page.context.cookies()
        target_domain = "buff.163.com"
        filtered_cookies = []
        print(cookies)
        for cookie in cookies:
            if cookie["domain"] == target_domain:
                filtered_cookies.append(cookie)
        await page.wait_for_timeout(20000)  # wait 20 seconds for you to log in

        # Close the browser when done
        await browser.close()
        return filtered_cookies

# %%
#now, use the name of items, and fetch the current market price
#Note: we do need cookies for this request.
from urllib.parse import quote
HEADERS2 = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36",
    "Referer": "https://buff.163.com/",
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "X-Requested-With": "XMLHttpRequest"
}
def get_market_price(market_hash_name,cookies_list):
    print(market_hash_name)
    base_url = "https://buff.163.com/api/market/goods"
    url = base_url + f"?game=csgo&page_num=1&search=" +quote(market_hash_name)
    #We need the cookies input manually, or getting the cookies on a logged on browser onto steam automatically
    #Seems like buff also using session. We can copy and extract the cookies from an logged in browser, but for automation process, its not practical.
    # cookie_str = f""
    cookies = {c['name']: c['value'] for c in cookies_list}
    resp = requests.get(url,headers=HEADERS,cookies= cookies)
    #update: we wont need cookies, just change the url to http, instead of https.
    # resp = requests.get(url,headers=HEADERS2)
    if (resp.status_code == 200):
        data = resp.json()
    
    if "data" not in data or not data["data"]["items"]:
        print("No matching items found.")
        return None
    items = data["data"]["items"]

    matched_item = None
    for item in items:
        if item["market_hash_name"] == market_hash_name:
            matched_item = item
            break
    
    if not matched_item:
        print("Item found but names do not exactly match.")
        return None
    else:
    #converting the return data to match with steam's response
        result = {
            market_hash_name: {
                "lowest_price": f"${matched_item['sell_min_price']}",
                "median_price": f"${matched_item['quick_price']}",
                "volume": str(matched_item["sell_num"])
            }
    }
        return result

# %%
cookies_list = await login_site_and_get_cookies()

# %%
import time
import random
from collections import defaultdict
data_by_timestamp = defaultdict(dict)
timestamp = int(time.time())
for item in item_summaries:
    name = item["market_hash_name"]
    price_info = get_market_price(name,cookies_list)
    
    if price_info:
        print(price_info)
        #data_by_timestamp[timestamp][name] = price_info
    #     print(f"{name}: {price_info['lowest_price']} (median: {price_info['median_price']})")
    else:
        print(f"{name}: Price not found")
    #adding delays for bypass steam's rate limiting
    time.sleep(random.uniform(4.5, 6.0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 8
#       6 for item in item_summaries:
#       7     name = item["market_hash_name"]
# ----> 8     price_info = get_market_price(name)
#      10     if price_info:
#      11         print(price_info)
#
# TypeError: get_market_price() missing 1 required positional argument: 'cookies_list'

# %%
cookies_list = await login_site_and_get_cookies()
print(cookies_list)
# cookies = "Device-Id=OsUryWgyoylmSL2KP4ig; Locale-Supported=en; game=csgo; session=1-nSeow00GiYG2BitmdCGbVvI77JaQyTV1YlDKB42gHRgf2038416215; client_id=CTyt1OV8TI2ulw7qngZKsA; account__pre_login__steam_key=667aa491fe3fcb990058445083951a92000db2e4813d05fe4bd2be5c0d937512; csrf_token=IjA1NGNiM2I2NmZjOTM4NjQ2MmU3YTNlOGRhMmViYTY5OGQ2OGVhZWQi.aRoGHQ.gLhi5gzdYD3tDP--RCVzFZGSaxw"
# cookies = {c['name']: c['value'] for c in cookies_str}
get_market_price("Kukri Knife | Night Stripe (Field-Tested)",cookies_list)
# Out:
# ---------------------------------------------------------------------------
# TargetClosedError                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 cookies_list = await login_site_and_get_cookies()
#       2 print(cookies_list)
#       3 # cookies = "Device-Id=OsUryWgyoylmSL2KP4ig; Locale-Supported=en; game=csgo; session=1-nSeow00GiYG2BitmdCGbVvI77JaQyTV1YlDKB42gHRgf2038416215; client_id=CTyt1OV8TI2ulw7qngZKsA; account__pre_login__steam_key=667aa491fe3fcb990058445083951a92000db2e4813d05fe4bd2be5c0d937512; csrf_token=IjA1NGNiM2I2NmZjOTM4NjQ2MmU3YTNlOGRhMmViYTY5OGQ2OGVhZWQi.aRoGHQ.gLhi5gzdYD3tDP--RCVzFZGSaxw"
#       4 # cookies = {c['name']: c['value'] for c in cookies_str}
#
# Cell In[13], line 8, in login_site_and_get_cookies()
#       5 context = await browser.new_context()
#       7 page = await browser.new_page()
# ----> 8 await page.goto("http://buff.163.com")
#      10 # Wait for login button or perform manual login
#      11 await page.click("text=Login/Register")
#
# File ~/DE_Projects/DEProj_CS2_Inventory_Monitoring/.venv/lib/python3.12/site-packages/playwright/async_api/_generated.py:8992, in Page.goto(self, url, timeout, wait_until, referer)
#    8931 async def goto(
#    8932     self,
#    8933     url: str,
#    (...)   8939     referer: typing.Optional[str] = None,
#    8940 ) -> typing.Optional["Response"]:
#    8941     """Page.goto
#    8942
#    8943     Returns the main resource response. In case of multiple redirects, the navigation will resolve with the first
#    (...)   8988     Union[Response, None]
#    8989     """
#    8991     return mapping.from_impl_nullable(
# -> 8992         await self._impl_obj.goto(
#    8993             url=url, timeout=timeout, waitUntil=wait_until, referer=referer
#    8994         )
#    8995     )
#
# File ~/DE_Projects/DEProj_CS2_Inventory_Monitoring/.venv/lib/python3.12/site-packages/playwright/_impl/_page.py:556, in Page.goto(self, url, timeout, waitUntil, referer)
#     549 async def goto(
#     550     self,
#     551     url: str,
#    (...)    554     referer: str = None,
#     555 ) -> Optional[Response]:
# --> 556     return await self._main_frame.goto(**locals_to_params(locals()))
#
# File ~/DE_Projects/DEProj_CS2_Inventory_Monitoring/.venv/lib/python3.12/site-packages/playwright/_impl/_frame.py:153, in Frame.goto(self, url, timeout, waitUntil, referer)
#     143 async def goto(
#     144     self,
#     145     url: str,
#    (...)    148     referer: str = None,
#     149 ) -> Optional[Response]:
#     150     return cast(
#     151         Optional[Response],
#     152         from_nullable_channel(
# --> 153             await self._channel.send(
#     154                 "goto", self._navigation_timeout, locals_to_params(locals())
#     155             )
#     156         ),
#     157     )
#
# File ~/DE_Projects/DEProj_CS2_Inventory_Monitoring/.venv/lib/python3.12/site-packages/playwright/_impl/_connection.py:69, in Channel.send(self, method, timeout_calculator, params, is_internal, title)
#      61 async def send(
#      62     self,
#      63     method: str,
#    (...)     67     title: str = None,
#      68 ) -> Any:
# ---> 69     return await self._connection.wrap_api_call(
#      70         lambda: self._inner_send(method, timeout_calculator, params, False),
#      71         is_internal,
#      72         title,
#      73     )
#
# File ~/DE_Projects/DEProj_CS2_Inventory_Monitoring/.venv/lib/python3.12/site-packages/playwright/_impl/_connection.py:558, in Connection.wrap_api_call(self, cb, is_internal, title)
#     556     return await cb()
#     557 except Exception as error:
# --> 558     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     559 finally:
#     560     self._api_zone.set(None)
#
# TargetClosedError: Page.goto: Target page, context or browser has been closed
# Call log:
#   - navigating to "http://buff.163.com/", waiting until "load"

# %%
get_market_price("★ Kukri Knife | Night Stripe (Field-Tested)",cookies_list)
# Out:
# ★ Kukri Knife | Night Stripe (Field-Tested)
# {'★ Kukri Knife | Night Stripe (Field-Tested)': {'lowest_price': '$439',
#   'median_price': '$438.5',
#   'volume': '154'}}
