# %%
#firstly, extracting all items inside a user's iventory (only cs2 items)
import requests
import time
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/117.0.0.0 Safari/537.36"
}
def fetch_inventory_page(steamid64: str, appid: int, contextid: int, start: str = None):
    url = f"https://steamcommunity.com/inventory/{steamid64}/{appid}/{contextid}"
    resp = requests.get(url,headers=HEADERS, timeout=15)
    resp.raise_for_status()
    return resp.json()
def inventory_items_for_user(steamid64: str, appid: int, contextid: int, delay_between_requests: float = 0.5):
    items = []
    seen_assetids = set()
    start = None

    while True:
        data = fetch_inventory_page(steamid64, appid, contextid, start)
        # check if inventory is private or empty
        if not data or "assets" not in data or "descriptions" not in data:
            # Might be private or zero items; return whatever we have or raise
            return items, data

        assets = data.get("assets", [])
        descriptions = data.get("descriptions", [])

        # Build lookup for descriptions by (classid, instanceid)
        desc_lookup = {}
        for d in descriptions:
            key = (str(d.get("classid")), str(d.get("instanceid", "0")))
            desc_lookup[key] = d

        for a in assets:
            assetid = a.get("assetid")  # unique per item
            if assetid in seen_assetids:
                continue
            seen_assetids.add(assetid)

            classid = str(a.get("classid"))
            instanceid = str(a.get("instanceid", "0"))
            desc = desc_lookup.get((classid, instanceid)) or {}

            item = {
                "assetid": assetid,
                "classid": classid,
                "instanceid": instanceid,
                "amount": a.get("amount", 1),
                "market_tradable_restriction": a.get("market_tradable_restriction"),
                # descriptive fields:
                "name": desc.get("name"),
                "type": desc.get("type"),
                "market_hash_name": desc.get("market_hash_name"),
                "tradable": desc.get("tradable"),
                "tags": desc.get("tags", []),
                "marketable": desc.get("marketable"),
                # entire desc for debugging
                "description_raw": desc
            }
            if item["tradable"] ==1 and item["marketable"] == 1:
                items.append(item)

        # pagination
        more = data.get("more_items") or False
        # some responses give 'last_assetid' to use as start; others use 'more_start'
        if more:
            start = data.get("last_assetid") or data.get("more_start")
            if not start:
                # fallback: if server indicates 'more_items' but no token, stop to avoid infinite loop
                break
            time.sleep(delay_between_requests)  # be polite
        else:
            break

    return items, data

# %%
steamid64 = "76561198923974658"   # example SteamID64
appid = 730                       # CS:GO/CS2 (confirm)
contextid = 2                     

items, raw = inventory_items_for_user(steamid64, appid, contextid)
print(f"Found {len(items)} items")
for i, it in enumerate(items[:200], start=1):
    print(f"{i}. {it['name']!r} {it['market_hash_name']!r} ({it['assetid']}) - tradable={it.get('tradable')} marketable={it.get('marketable')}")
# Out:
# Found 46 items
# 1. 'SSG 08 | Blue Spruce' 'SSG 08 | Blue Spruce (Field-Tested)' (47501101767) - tradable=1 marketable=1
# 2. 'Dreams & Nightmares Case' 'Dreams & Nightmares Case' (47501101766) - tradable=1 marketable=1
# 3. 'StatTrak™ MAG-7 | Insomnia' 'StatTrak™ MAG-7 | Insomnia (Battle-Scarred)' (47394323285) - tradable=1 marketable=1
# 4. 'Sticker | Aleksib (Gold) | Copenhagen 2024' 'Sticker | Aleksib (Gold) | Copenhagen 2024' (47386508166) - tradable=1 marketable=1
# 5. 'StatTrak™ M4A4 | Choppa' 'StatTrak™ M4A4 | Choppa (Field-Tested)' (47381099310) - tradable=1 marketable=1
# 6. 'FAMAS | Meow 36' 'FAMAS | Meow 36 (Minimal Wear)' (47380823343) - tradable=1 marketable=1
# 7. 'Glock-18 | Block-18' 'Glock-18 | Block-18 (Field-Tested)' (47380815253) - tradable=1 marketable=1
# 8. '★ Kukri Knife | Night Stripe' '★ Kukri Knife | Night Stripe (Field-Tested)' (47380789813) - tradable=1 marketable=1
# 9. 'Revolution Case' 'Revolution Case' (47185843227) - tradable=1 marketable=1
# 10. 'MP5-SD | Dirt Drop' 'MP5-SD | Dirt Drop (Field-Tested)' (47017281017) - tradable=1 marketable=1
# 11. 'MP9 | Buff Blue' 'MP9 | Buff Blue (Battle-Scarred)' (46861180799) - tradable=1 marketable=1
# 12. 'Sticker | Nemiga (Foil) | Austin 2025' 'Sticker | Nemiga (Foil) | Austin 2025' (46772516572) - tradable=1 marketable=1
# 13. 'Sticker | broky (Foil) | Austin 2025' 'Sticker | broky (Foil) | Austin 2025' (46497303228) - tradable=1 marketable=1
# 14. 'Sticker | m0NESY (Foil) | Austin 2025' 'Sticker | m0NESY (Foil) | Austin 2025' (46497275563) - tradable=1 marketable=1
# 15. 'Sticker | Heavygod (Gold) | Austin 2025' 'Sticker | Heavygod (Gold) | Austin 2025' (46497253994) - tradable=1 marketable=1
# 16. 'Sticker | m0NESY | Austin 2025' 'Sticker | m0NESY | Austin 2025' (46148245762) - tradable=1 marketable=1
# 17. 'Sticker | broky (Foil) | Austin 2025' 'Sticker | broky (Foil) | Austin 2025' (46148219333) - tradable=1 marketable=1
# 18. 'Sticker | TYLOO | Austin 2025' 'Sticker | TYLOO | Austin 2025' (46148217313) - tradable=1 marketable=1
# 19. 'Sticker | EliGE (Foil) | Austin 2025' 'Sticker | EliGE (Foil) | Austin 2025' (46148214852) - tradable=1 marketable=1
# 20. 'Sticker | MOUZ (Glitter) | Shanghai 2024' 'Sticker | MOUZ (Glitter) | Shanghai 2024' (46133005348) - tradable=1 marketable=1
# 21. 'Sticker | Wildcard (Foil) | Austin 2025' 'Sticker | Wildcard (Foil) | Austin 2025' (46132036204) - tradable=1 marketable=1
# 22. 'Sticker | magixx (Holo) | Austin 2025' 'Sticker | magixx (Holo) | Austin 2025' (45987081099) - tradable=1 marketable=1
# 23. 'Sticker | m0NESY | Austin 2025' 'Sticker | m0NESY | Austin 2025' (45986319959) - tradable=1 marketable=1
# 24. 'Sticker | donk (Foil) | Austin 2025' 'Sticker | donk (Foil) | Austin 2025' (45986314792) - tradable=1 marketable=1
# 25. 'Sticker | NiKo | Austin 2025' 'Sticker | NiKo | Austin 2025' (45986308420) - tradable=1 marketable=1
# 26. 'Nova | Mandrel' 'Nova | Mandrel (Factory New)' (45986284062) - tradable=1 marketable=1
# 27. 'Sticker | electronic (Holo) | Paris 2023' 'Sticker | electronic (Holo) | Paris 2023' (45943051137) - tradable=1 marketable=1
# 28. 'Fracture Case' 'Fracture Case' (45871479392) - tradable=1 marketable=1
# 29. 'Sticker | NiKo | Austin 2025' 'Sticker | NiKo | Austin 2025' (45732510491) - tradable=1 marketable=1
# 30. 'Fracture Case' 'Fracture Case' (42754392735) - tradable=1 marketable=1
# 31. 'Fracture Case' 'Fracture Case' (41072907907) - tradable=1 marketable=1
# 32. 'Fracture Case' 'Fracture Case' (40988881325) - tradable=1 marketable=1
# 33. 'Fracture Case' 'Fracture Case' (40653506177) - tradable=1 marketable=1
# 34. 'Fracture Case' 'Fracture Case' (40352470701) - tradable=1 marketable=1
# 35. 'AWP | PAW' 'AWP | PAW (Minimal Wear)' (39069764130) - tradable=1 marketable=1
# 36. 'FAMAS | ZX Spectron' 'FAMAS | ZX Spectron (Field-Tested)' (33408390949) - tradable=1 marketable=1
# 37. 'StatTrak™ MP9 | Bioleak' 'StatTrak™ MP9 | Bioleak (Field-Tested)' (32945349271) - tradable=1 marketable=1
# 38. 'Galil AR | Chromatic Aberration' 'Galil AR | Chromatic Aberration (Field-Tested)' (32888343534) - tradable=1 marketable=1
# 39. 'Five-SeveN | Boost Protocol' 'Five-SeveN | Boost Protocol (Minimal Wear)' (32888328097) - tradable=1 marketable=1
# 40. 'StatTrak™ Glock-18 | Winterized' 'StatTrak™ Glock-18 | Winterized (Minimal Wear)' (27105044325) - tradable=1 marketable=1
# 41. 'P2000 | Gnarled' 'P2000 | Gnarled (Factory New)' (26889559365) - tradable=1 marketable=1
# 42. 'AK-47 | Point Disarray' 'AK-47 | Point Disarray (Field-Tested)' (25103319014) - tradable=1 marketable=1
# 43. 'USP-S | Cyrex' 'USP-S | Cyrex (Minimal Wear)' (25044310415) - tradable=1 marketable=1
# 44. 'M4A1-S | Leaded Glass' 'M4A1-S | Leaded Glass (Field-Tested)' (24831369865) - tradable=1 marketable=1
# 45. 'Music Kit | Neck Deep, The Lowlife Pack' 'Music Kit | Neck Deep, The Lowlife Pack' (24820448486) - tradable=1 marketable=1
# 46. 'MAC-10 | Disco Tech' 'MAC-10 | Disco Tech (Field-Tested)' (24754560599) - tradable=1 marketable=1

# %%
item_summaries = []#this for latter fetch on marketoverpice
seen_names = set()#this for checking duplicates market_hash_name
for i, it in enumerate(items[:200], start=1):
    name = it['market_hash_name']
    #skip if name are already added
    if not name or name in seen_names:
        continue
    seen_names.add(name)
    summary = {
        "index": i,
        "name": it['name'],
        "market_hash_name": it['market_hash_name'],
        "tradable": it.get('tradable'),
        "marketable": it.get('marketable')
    }
    item_summaries.append(summary)

print(item_summaries)
# Out:
# [{'index': 1, 'name': 'SSG 08 | Blue Spruce', 'market_hash_name': 'SSG 08 | Blue Spruce (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 2, 'name': 'Dreams & Nightmares Case', 'market_hash_name': 'Dreams & Nightmares Case', 'tradable': 1, 'marketable': 1}, {'index': 3, 'name': 'StatTrak™ MAG-7 | Insomnia', 'market_hash_name': 'StatTrak™ MAG-7 | Insomnia (Battle-Scarred)', 'tradable': 1, 'marketable': 1}, {'index': 4, 'name': 'Sticker | Aleksib (Gold) | Copenhagen 2024', 'market_hash_name': 'Sticker | Aleksib (Gold) | Copenhagen 2024', 'tradable': 1, 'marketable': 1}, {'index': 5, 'name': 'StatTrak™ M4A4 | Choppa', 'market_hash_name': 'StatTrak™ M4A4 | Choppa (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 6, 'name': 'FAMAS | Meow 36', 'market_hash_name': 'FAMAS | Meow 36 (Minimal Wear)', 'tradable': 1, 'marketable': 1}, {'index': 7, 'name': 'Glock-18 | Block-18', 'market_hash_name': 'Glock-18 | Block-18 (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 8, 'name': '★ Kukri Knife | Night Stripe', 'market_hash_name': '★ Kukri Knife | Night Stripe (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 9, 'name': 'Revolution Case', 'market_hash_name': 'Revolution Case', 'tradable': 1, 'marketable': 1}, {'index': 10, 'name': 'MP5-SD | Dirt Drop', 'market_hash_name': 'MP5-SD | Dirt Drop (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 11, 'name': 'MP9 | Buff Blue', 'market_hash_name': 'MP9 | Buff Blue (Battle-Scarred)', 'tradable': 1, 'marketable': 1}, {'index': 12, 'name': 'Sticker | Nemiga (Foil) | Austin 2025', 'market_hash_name': 'Sticker | Nemiga (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 13, 'name': 'Sticker | broky (Foil) | Austin 2025', 'market_hash_name': 'Sticker | broky (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 14, 'name': 'Sticker | m0NESY (Foil) | Austin 2025', 'market_hash_name': 'Sticker | m0NESY (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 15, 'name': 'Sticker | Heavygod (Gold) | Austin 2025', 'market_hash_name': 'Sticker | Heavygod (Gold) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 16, 'name': 'Sticker | m0NESY | Austin 2025', 'market_hash_name': 'Sticker | m0NESY | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 18, 'name': 'Sticker | TYLOO | Austin 2025', 'market_hash_name': 'Sticker | TYLOO | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 19, 'name': 'Sticker | EliGE (Foil) | Austin 2025', 'market_hash_name': 'Sticker | EliGE (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 20, 'name': 'Sticker | MOUZ (Glitter) | Shanghai 2024', 'market_hash_name': 'Sticker | MOUZ (Glitter) | Shanghai 2024', 'tradable': 1, 'marketable': 1}, {'index': 21, 'name': 'Sticker | Wildcard (Foil) | Austin 2025', 'market_hash_name': 'Sticker | Wildcard (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 22, 'name': 'Sticker | magixx (Holo) | Austin 2025', 'market_hash_name': 'Sticker | magixx (Holo) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 24, 'name': 'Sticker | donk (Foil) | Austin 2025', 'market_hash_name': 'Sticker | donk (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 25, 'name': 'Sticker | NiKo | Austin 2025', 'market_hash_name': 'Sticker | NiKo | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 26, 'name': 'Nova | Mandrel', 'market_hash_name': 'Nova | Mandrel (Factory New)', 'tradable': 1, 'marketable': 1}, {'index': 27, 'name': 'Sticker | electronic (Holo) | Paris 2023', 'market_hash_name': 'Sticker | electronic (Holo) | Paris 2023', 'tradable': 1, 'marketable': 1}, {'index': 28, 'name': 'Fracture Case', 'market_hash_name': 'Fracture Case', 'tradable': 1, 'marketable': 1}, {'index': 35, 'name': 'AWP | PAW', 'market_hash_name': 'AWP | PAW (Minimal Wear)', 'tradable': 1, 'marketable': 1}, {'index': 36, 'name': 'FAMAS | ZX Spectron', 'market_hash_name': 'FAMAS | ZX Spectron (Field-Tested)', 'tradable': 1, 'marketa ...

# %%
#now, use the name of items, and fetch the current market price
#Note: we do need cookies for this request.
from urllib.parse import quote
def get_market_price(market_hash_name):
    base_url = "http://buff.163.com/api/market/good"
    url = base_url + f"?game=csgo&page_num=1&search=" +quote(market_hash_name)
    #We need the cookies input manually, or getting the cookies on a logged on browser onto steam automatically
    # cookie_str = ""

    # cookies = dict(item.split("=", 1) for item in cookie_str.split("; "))
    # resp = requests.get(url,headers=HEADERS,cookies=cookies)
    #update: we wont need cookies, just change the url to http, instead of https.
    resp = requests.get(url,headers=HEADERS)
    data = resp.json() 

    if data.get("success"):
        return data
        # #these 3 infos below can be null/none, for case like there is no one selling -> no median price + volumn on market. Not sure on lowest_price tho.
        # return {
        #         "lowest_price": data.get("lowest_price"),
        #         "median_price": data.get("median_price"),
        #         "volume": data.get("volume")
        #     }
    #
    else:
        return None

# %%
import time
import random
from collections import defaultdict
data_by_timestamp = defaultdict(dict)
timestamp = int(time.time())
for item in item_summaries:
    name = item["market_hash_name"]
    price_info = get_market_price(name)
    
    if price_info:
        data_by_timestamp[timestamp][name] = price_info
    #     print(f"{name}: {price_info['lowest_price']} (median: {price_info['median_price']})")
    else:
        print(f"{name}: Price not found")
    #adding delays for bypass steam's rate limiting
    time.sleep(random.uniform(4.5, 6.0))

print("final data")
#this data now can be saved for further usage
#the data structure can be changed, since there can be alot more apis need to be fetch, but this is my intention for the final structure.
print(data_by_timestamp)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/DE_Projects/DEProj_CS2_Inventory_Monitoring/.venv/lib/python3.12/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /usr/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /usr/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /usr/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 2 column 5 (char 5)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[15], line 8
#       6 for item in item_summaries:
#       7     name = item["market_hash_name"]
# ----> 8     price_info = get_market_price(name)
#      10     if price_info:
#      11         data_by_timestamp[timestamp][name] = price_info
#
# Cell In[14], line 14, in get_market_price(market_hash_name)
#       7 #We need the cookies input manually, or getting the cookies on a logged on browser onto steam automatically
#       8 # cookie_str = ""
#       9
#      10 # cookies = dict(item.split("=", 1) for item in cookie_str.split("; "))
#      11 # resp = requests.get(url,headers=HEADERS,cookies=cookies)
#      12 #update: we wont need cookies, just change the url to http, instead of https.
#      13 resp = requests.get(url,headers=HEADERS)
# ---> 14 data = resp.json()
#      16 if data.get("success"):
#      17     return data
#
# File ~/DE_Projects/DEProj_CS2_Inventory_Monitoring/.venv/lib/python3.12/site-packages/requests/models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 2 column 5 (char 5)
