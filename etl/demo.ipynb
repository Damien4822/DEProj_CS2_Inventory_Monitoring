# %%
#firstly, extracting all items inside a user's iventory (only cs2 items)
import requests
import time
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/117.0.0.0 Safari/537.36"
}
def fetch_inventory_page(steamid64: str, appid: int, contextid: int, start: str = None):
    url = f"https://steamcommunity.com/inventory/{steamid64}/{appid}/{contextid}"
    resp = requests.get(url,headers=HEADERS, timeout=15)
    resp.raise_for_status()
    return resp.json()
def inventory_items_for_user(steamid64: str, appid: int, contextid: int, delay_between_requests: float = 0.5):
    items = []
    seen_assetids = set()
    start = None

    while True:
        data = fetch_inventory_page(steamid64, appid, contextid, start)
        # check if inventory is private or empty
        if not data or "assets" not in data or "descriptions" not in data:
            # Might be private or zero items; return whatever we have or raise
            return items, data

        assets = data.get("assets", [])
        descriptions = data.get("descriptions", [])

        # Build lookup for descriptions by (classid, instanceid)
        desc_lookup = {}
        for d in descriptions:
            key = (str(d.get("classid")), str(d.get("instanceid", "0")))
            desc_lookup[key] = d

        for a in assets:
            assetid = a.get("assetid")  # unique per item
            if assetid in seen_assetids:
                continue
            seen_assetids.add(assetid)

            classid = str(a.get("classid"))
            instanceid = str(a.get("instanceid", "0"))
            desc = desc_lookup.get((classid, instanceid)) or {}

            item = {
                "assetid": assetid,
                "classid": classid,
                "instanceid": instanceid,
                "amount": a.get("amount", 1),
                "market_tradable_restriction": a.get("market_tradable_restriction"),
                # descriptive fields:
                "name": desc.get("name"),
                "type": desc.get("type"),
                "market_hash_name": desc.get("market_hash_name"),
                "tradable": desc.get("tradable"),
                "tags": desc.get("tags", []),
                "marketable": desc.get("marketable"),
                # entire desc for debugging
                "description_raw": desc
            }
            if item["tradable"] ==1 and item["marketable"] == 1:
                items.append(item)

        # pagination
        more = data.get("more_items") or False
        # some responses give 'last_assetid' to use as start; others use 'more_start'
        if more:
            start = data.get("last_assetid") or data.get("more_start")
            if not start:
                # fallback: if server indicates 'more_items' but no token, stop to avoid infinite loop
                break
            time.sleep(delay_between_requests)  # be polite
        else:
            break

    return items, data

# %%
steamid64 = "76561198923974658"   # example SteamID64
appid = 730                       # CS:GO/CS2 (confirm)
contextid = 2                     

items, raw = inventory_items_for_user(steamid64, appid, contextid)
print(f"Found {len(items)} items")
for i, it in enumerate(items[:200], start=1):
    print(f"{i}. {it['name']!r} {it['market_hash_name']!r} ({it['assetid']}) - tradable={it.get('tradable')} marketable={it.get('marketable')}")
# Out:
# Found 41 items
# 1. 'SSG 08 | Blue Spruce' 'SSG 08 | Blue Spruce (Field-Tested)' (47501101767) - tradable=1 marketable=1
# 2. 'Sticker | Aleksib (Gold) | Copenhagen 2024' 'Sticker | Aleksib (Gold) | Copenhagen 2024' (47386508166) - tradable=1 marketable=1
# 3. 'Dreams & Nightmares Case' 'Dreams & Nightmares Case' (47501101766) - tradable=1 marketable=1
# 4. 'Revolution Case' 'Revolution Case' (47185843227) - tradable=1 marketable=1
# 5. 'MP5-SD | Dirt Drop' 'MP5-SD | Dirt Drop (Field-Tested)' (47017281017) - tradable=1 marketable=1
# 6. 'MP9 | Buff Blue' 'MP9 | Buff Blue (Battle-Scarred)' (46861180799) - tradable=1 marketable=1
# 7. 'Sticker | Nemiga (Foil) | Austin 2025' 'Sticker | Nemiga (Foil) | Austin 2025' (46772516572) - tradable=1 marketable=1
# 8. 'Sticker | broky (Foil) | Austin 2025' 'Sticker | broky (Foil) | Austin 2025' (46497303228) - tradable=1 marketable=1
# 9. 'Sticker | m0NESY (Foil) | Austin 2025' 'Sticker | m0NESY (Foil) | Austin 2025' (46497275563) - tradable=1 marketable=1
# 10. 'Sticker | Heavygod (Gold) | Austin 2025' 'Sticker | Heavygod (Gold) | Austin 2025' (46497253994) - tradable=1 marketable=1
# 11. 'Sticker | m0NESY | Austin 2025' 'Sticker | m0NESY | Austin 2025' (46148245762) - tradable=1 marketable=1
# 12. 'Sticker | broky (Foil) | Austin 2025' 'Sticker | broky (Foil) | Austin 2025' (46148219333) - tradable=1 marketable=1
# 13. 'Sticker | TYLOO | Austin 2025' 'Sticker | TYLOO | Austin 2025' (46148217313) - tradable=1 marketable=1
# 14. 'Sticker | EliGE (Foil) | Austin 2025' 'Sticker | EliGE (Foil) | Austin 2025' (46148214852) - tradable=1 marketable=1
# 15. 'Sticker | MOUZ (Glitter) | Shanghai 2024' 'Sticker | MOUZ (Glitter) | Shanghai 2024' (46133005348) - tradable=1 marketable=1
# 16. 'Sticker | Wildcard (Foil) | Austin 2025' 'Sticker | Wildcard (Foil) | Austin 2025' (46132036204) - tradable=1 marketable=1
# 17. 'Sticker | magixx (Holo) | Austin 2025' 'Sticker | magixx (Holo) | Austin 2025' (45987081099) - tradable=1 marketable=1
# 18. 'Sticker | m0NESY | Austin 2025' 'Sticker | m0NESY | Austin 2025' (45986319959) - tradable=1 marketable=1
# 19. 'Sticker | donk (Foil) | Austin 2025' 'Sticker | donk (Foil) | Austin 2025' (45986314792) - tradable=1 marketable=1
# 20. 'Sticker | NiKo | Austin 2025' 'Sticker | NiKo | Austin 2025' (45986308420) - tradable=1 marketable=1
# 21. 'Nova | Mandrel' 'Nova | Mandrel (Factory New)' (45986284062) - tradable=1 marketable=1
# 22. 'Sticker | electronic (Holo) | Paris 2023' 'Sticker | electronic (Holo) | Paris 2023' (45943051137) - tradable=1 marketable=1
# 23. 'Fracture Case' 'Fracture Case' (45871479392) - tradable=1 marketable=1
# 24. 'Sticker | NiKo | Austin 2025' 'Sticker | NiKo | Austin 2025' (45732510491) - tradable=1 marketable=1
# 25. 'Fracture Case' 'Fracture Case' (42754392735) - tradable=1 marketable=1
# 26. 'Fracture Case' 'Fracture Case' (41072907907) - tradable=1 marketable=1
# 27. 'Fracture Case' 'Fracture Case' (40988881325) - tradable=1 marketable=1
# 28. 'Fracture Case' 'Fracture Case' (40653506177) - tradable=1 marketable=1
# 29. 'Fracture Case' 'Fracture Case' (40352470701) - tradable=1 marketable=1
# 30. 'AWP | PAW' 'AWP | PAW (Minimal Wear)' (39069764130) - tradable=1 marketable=1
# 31. 'FAMAS | ZX Spectron' 'FAMAS | ZX Spectron (Field-Tested)' (33408390949) - tradable=1 marketable=1
# 32. 'StatTrak™ MP9 | Bioleak' 'StatTrak™ MP9 | Bioleak (Field-Tested)' (32945349271) - tradable=1 marketable=1
# 33. 'Galil AR | Chromatic Aberration' 'Galil AR | Chromatic Aberration (Field-Tested)' (32888343534) - tradable=1 marketable=1
# 34. 'Five-SeveN | Boost Protocol' 'Five-SeveN | Boost Protocol (Minimal Wear)' (32888328097) - tradable=1 marketable=1
# 35. 'StatTrak™ Glock-18 | Winterized' 'StatTrak™ Glock-18 | Winterized (Minimal Wear)' (27105044325) - tradable=1 marketable=1
# 36. 'P2000 | Gnarled' 'P2000 | Gnarled (Factory New)' (26889559365) - tradable=1 marketable=1
# 37. 'AK-47 | Point Disarray' 'AK-47 | Point Disarray (Field-Tested)' (25103319014) - tradable=1 marketable=1
# 38. 'USP-S | Cyrex' 'USP-S | Cyrex (Minimal Wear)' (25044310415) - tradable=1 marketable=1
# 39. 'M4A1-S | Leaded Glass' 'M4A1-S | Leaded Glass (Field-Tested)' (24831369865) - tradable=1 marketable=1
# 40. 'Music Kit | Neck Deep, The Lowlife Pack' 'Music Kit | Neck Deep, The Lowlife Pack' (24820448486) - tradable=1 marketable=1
# 41. 'MAC-10 | Disco Tech' 'MAC-10 | Disco Tech (Field-Tested)' (24754560599) - tradable=1 marketable=1

# %%
item_summaries = []#this for latter fetch on marketoverpice
seen_names = set()#this for checking duplicates market_hash_name
for i, it in enumerate(items[:200], start=1):
    name = it['market_hash_name']
    #skip if name are already added
    if not name or name in seen_names:
        continue
    seen_names.add(name)
    summary = {
        "index": i,
        "name": it['name'],
        "market_hash_name": it['market_hash_name'],
        "tradable": it.get('tradable'),
        "marketable": it.get('marketable')
    }
    item_summaries.append(summary)

print(item_summaries)
# Out:
# [{'index': 1, 'name': 'SSG 08 | Blue Spruce', 'market_hash_name': 'SSG 08 | Blue Spruce (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 2, 'name': 'Sticker | Aleksib (Gold) | Copenhagen 2024', 'market_hash_name': 'Sticker | Aleksib (Gold) | Copenhagen 2024', 'tradable': 1, 'marketable': 1}, {'index': 3, 'name': 'Dreams & Nightmares Case', 'market_hash_name': 'Dreams & Nightmares Case', 'tradable': 1, 'marketable': 1}, {'index': 4, 'name': 'Revolution Case', 'market_hash_name': 'Revolution Case', 'tradable': 1, 'marketable': 1}, {'index': 5, 'name': 'MP5-SD | Dirt Drop', 'market_hash_name': 'MP5-SD | Dirt Drop (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 6, 'name': 'MP9 | Buff Blue', 'market_hash_name': 'MP9 | Buff Blue (Battle-Scarred)', 'tradable': 1, 'marketable': 1}, {'index': 7, 'name': 'Sticker | Nemiga (Foil) | Austin 2025', 'market_hash_name': 'Sticker | Nemiga (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 8, 'name': 'Sticker | broky (Foil) | Austin 2025', 'market_hash_name': 'Sticker | broky (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 9, 'name': 'Sticker | m0NESY (Foil) | Austin 2025', 'market_hash_name': 'Sticker | m0NESY (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 10, 'name': 'Sticker | Heavygod (Gold) | Austin 2025', 'market_hash_name': 'Sticker | Heavygod (Gold) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 11, 'name': 'Sticker | m0NESY | Austin 2025', 'market_hash_name': 'Sticker | m0NESY | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 13, 'name': 'Sticker | TYLOO | Austin 2025', 'market_hash_name': 'Sticker | TYLOO | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 14, 'name': 'Sticker | EliGE (Foil) | Austin 2025', 'market_hash_name': 'Sticker | EliGE (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 15, 'name': 'Sticker | MOUZ (Glitter) | Shanghai 2024', 'market_hash_name': 'Sticker | MOUZ (Glitter) | Shanghai 2024', 'tradable': 1, 'marketable': 1}, {'index': 16, 'name': 'Sticker | Wildcard (Foil) | Austin 2025', 'market_hash_name': 'Sticker | Wildcard (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 17, 'name': 'Sticker | magixx (Holo) | Austin 2025', 'market_hash_name': 'Sticker | magixx (Holo) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 19, 'name': 'Sticker | donk (Foil) | Austin 2025', 'market_hash_name': 'Sticker | donk (Foil) | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 20, 'name': 'Sticker | NiKo | Austin 2025', 'market_hash_name': 'Sticker | NiKo | Austin 2025', 'tradable': 1, 'marketable': 1}, {'index': 21, 'name': 'Nova | Mandrel', 'market_hash_name': 'Nova | Mandrel (Factory New)', 'tradable': 1, 'marketable': 1}, {'index': 22, 'name': 'Sticker | electronic (Holo) | Paris 2023', 'market_hash_name': 'Sticker | electronic (Holo) | Paris 2023', 'tradable': 1, 'marketable': 1}, {'index': 23, 'name': 'Fracture Case', 'market_hash_name': 'Fracture Case', 'tradable': 1, 'marketable': 1}, {'index': 30, 'name': 'AWP | PAW', 'market_hash_name': 'AWP | PAW (Minimal Wear)', 'tradable': 1, 'marketable': 1}, {'index': 31, 'name': 'FAMAS | ZX Spectron', 'market_hash_name': 'FAMAS | ZX Spectron (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 32, 'name': 'StatTrak™ MP9 | Bioleak', 'market_hash_name': 'StatTrak™ MP9 | Bioleak (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 33, 'name': 'Galil AR | Chromatic Aberration', 'market_hash_name': 'Galil AR | Chromatic Aberration (Field-Tested)', 'tradable': 1, 'marketable': 1}, {'index': 34, 'name': 'Five-SeveN | Boost Protocol', 'market_hash_name': 'Five-SeveN | Boost Protocol (Minimal Wear)', 'tradable': 1, 'marketable': 1}, {'index': 35, 'name': 'StatTrak™ Glock-18 | Winterized', 'market_hash_name': 'StatTrak™ Glock-18 | Winterized (Minimal Wear)', 'tradable': 1, 'marketable': 1}, {'index': 36, 'name': 'P2000 | Gnarled', 'market_hash_name': 'P2000 | Gnarled (Factory N ...

# %%
#now, use the name of items, and fetch the current market price
#Note: we do need cookies for this request.
from urllib.parse import quote
def get_market_price(market_hash_name, appid=730, currency=1):
    base_url = "http://steamcommunity.com/market/priceoverview/"
    url = base_url + f"?appid={appid}&currency={currency}&market_hash_name=" + quote(market_hash_name)
    #We need the cookies input manually, or getting the cookies on a logged on browser onto steam automatically
    # cookie_str = ""

    # cookies = dict(item.split("=", 1) for item in cookie_str.split("; "))
    # resp = requests.get(url,headers=HEADERS,cookies=cookies)
    #update: we wont need cookies, just change the url to http, instead of https.
    resp = requests.get(url,headers=HEADERS)
    data = resp.json() 

    if data.get("success"):
        #these 3 infos below can be null/none, for case like there is no one selling -> no median price + volumn on market. Not sure on lowest_price tho.
        return {
                "lowest_price": data.get("lowest_price"),
                "median_price": data.get("median_price"),
                "volume": data.get("volume")
            }
    #
    else:
        return None

# %%
import time
import random
from collections import defaultdict
data_by_timestamp = defaultdict(dict)
timestamp = int(time.time())
for item in item_summaries:
    name = item["market_hash_name"]
    price_info = get_market_price(name)
    
    if price_info:
        data_by_timestamp[timestamp][name] = price_info
    #     print(f"{name}: {price_info['lowest_price']} (median: {price_info['median_price']})")
    else:
        print(f"{name}: Price not found")
    #adding delays for bypass steam's rate limiting
    time.sleep(random.uniform(4.5, 6.0))

print("final data")
#this data now can be saved for further usage
#the data structure can be changed, since there can be alot more apis need to be fetch, but this is my intention for the final structure.
print(data_by_timestamp)
# Out:
# Sticker | Aleksib (Gold) | Copenhagen 2024: Price not found
# final data
# defaultdict(<class 'dict'>, {1762102334: {'SSG 08 | Blue Spruce (Field-Tested)': {'lowest_price': '$0.04', 'median_price': '$0.02', 'volume': '2,958'}, 'Dreams & Nightmares Case': {'lowest_price': '$2.32', 'median_price': '$2.32', 'volume': '173,916'}, 'Revolution Case': {'lowest_price': '$0.57', 'median_price': '$0.58', 'volume': '121,154'}, 'MP5-SD | Dirt Drop (Field-Tested)': {'lowest_price': '$0.04', 'median_price': '$0.03', 'volume': '2,647'}, 'MP9 | Buff Blue (Battle-Scarred)': {'lowest_price': '$0.06', 'median_price': '$0.02', 'volume': '323'}, 'Sticker | Nemiga (Foil) | Austin 2025': {'lowest_price': '$0.25', 'median_price': '$0.25', 'volume': '301'}, 'Sticker | broky (Foil) | Austin 2025': {'lowest_price': '$0.31', 'median_price': '$0.30', 'volume': '46'}, 'Sticker | m0NESY (Foil) | Austin 2025': {'lowest_price': '$3.04', 'median_price': '$2.84', 'volume': '44'}, 'Sticker | Heavygod (Gold) | Austin 2025': {'lowest_price': '$2.82', 'median_price': '$2.83', 'volume': '2'}, 'Sticker | m0NESY | Austin 2025': {'lowest_price': '$0.26', 'median_price': '$0.26', 'volume': '137'}, 'Sticker | TYLOO | Austin 2025': {'lowest_price': '$0.18', 'median_price': '$0.18', 'volume': '1,989'}, 'Sticker | EliGE (Foil) | Austin 2025': {'lowest_price': '$0.50', 'median_price': '$0.40', 'volume': '29'}, 'Sticker | MOUZ (Glitter) | Shanghai 2024': {'lowest_price': '$0.48', 'median_price': '$0.47', 'volume': '269'}, 'Sticker | Wildcard (Foil) | Austin 2025': {'lowest_price': '$0.20', 'median_price': '$0.21', 'volume': '367'}, 'Sticker | magixx (Holo) | Austin 2025': {'lowest_price': '$3.57', 'median_price': '$3.38', 'volume': '25'}, 'Sticker | donk (Foil) | Austin 2025': {'lowest_price': '$1.35', 'median_price': '$1.41', 'volume': '127'}, 'Sticker | NiKo | Austin 2025': {'lowest_price': '$0.36', 'median_price': '$0.35', 'volume': '99'}, 'Nova | Mandrel (Factory New)': {'lowest_price': '$0.08', 'median_price': '$0.06', 'volume': '2,059'}, 'Sticker | electronic (Holo) | Paris 2023': {'lowest_price': '$0.93', 'median_price': '$0.77', 'volume': '10'}, 'Fracture Case': {'lowest_price': '$0.71', 'median_price': '$0.71', 'volume': '143,350'}, 'AWP | PAW (Minimal Wear)': {'lowest_price': '$4.15', 'median_price': '$4.03', 'volume': '242'}, 'FAMAS | ZX Spectron (Field-Tested)': {'lowest_price': '$4.43', 'median_price': '$4.35', 'volume': '176'}, 'StatTrak™ MP9 | Bioleak (Field-Tested)': {'lowest_price': '$0.50', 'median_price': '$0.45', 'volume': '62'}, 'Galil AR | Chromatic Aberration (Field-Tested)': {'lowest_price': '$4.62', 'median_price': '$5.08', 'volume': '529'}, 'Five-SeveN | Boost Protocol (Minimal Wear)': {'lowest_price': '$5.48', 'median_price': '$5.56', 'volume': '114'}, 'StatTrak™ Glock-18 | Winterized (Minimal Wear)': {'lowest_price': '$0.40', 'median_price': '$0.43', 'volume': '274'}, 'P2000 | Gnarled (Factory New)': {'lowest_price': '$0.86', 'median_price': '$0.85', 'volume': '96'}, 'AK-47 | Point Disarray (Field-Tested)': {'lowest_price': '$18.48', 'median_price': '$18.82', 'volume': '390'}, 'USP-S | Cyrex (Minimal Wear)': {'lowest_price': '$5.20', 'median_price': '$5.15', 'volume': '428'}, 'M4A1-S | Leaded Glass (Field-Tested)': {'lowest_price': '$10.07', 'median_price': '$10.10', 'volume': '702'}, 'Music Kit | Neck Deep, The Lowlife Pack': {'lowest_price': '$4.45', 'median_price': '$4.41', 'volume': '91'}, 'MAC-10 | Disco Tech (Field-Tested)': {'lowest_price': '$6.22', 'median_price': '$6.12', 'volume': '395'}}})
